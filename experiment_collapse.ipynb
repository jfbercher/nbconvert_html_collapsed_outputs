# %%
1+1
# Out:
# 2

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(np.random.randn(100))

# %%
ls *.png
# Out:
# 6d2fa8b6.plickers.iphone.png        icon2.png
# Capture du 2015-11-14 10-53-28.png  icon.png
# example_studentized_residuals.png   residuals_example.png
# icon1.png                           Screenshot from 2014-11-05 11:01:12.png

# %%
plt.plot(np.sin(2*np.pi*0.01*np.arange(200)))
